# %%
import pandas as pd

# Define the file path for the input text file and the output CSV file
input_file_path = 'allCountries.txt'
output_csv_path = 'geonames.csv'

# Define the column headers based on the structure you provided
column_headers = [
    "geonameid", "name", "asciiname", "alternatenames", "latitude", "longitude",
    "feature class", "feature code", "country code", "cc2", "admin1 code",
    "admin2 code", "admin3 code", "admin4 code", "population", "elevation", "dem",
    "timezone", "modification date"
]

# Use pandas to read the tab-delimited file
df = pd.read_csv(input_file_path, delimiter='\t', names=column_headers, low_memory=False)

# Save the DataFrame to a CSV file
df.to_csv(output_csv_path, index=False)

# Print the first few rows of the DataFrame to verify
print(df.head())
# Out:
#    geonameid                          name                     asciiname  \
# 0    2994701                     Roc Meler                     Roc Meler
# 1    3017832          Pic de les Abelletes          Pic de les Abelletes
# 2    3017833       Estany de les Abelletes       Estany de les Abelletes
# 3    3023203  Port Vieux de la Coume d’Ose  Port Vieux de la Coume d'Ose
# 4    3029315          Port de la Cabanette          Port de la Cabanette
#
#                                       alternatenames  latitude  longitude  \
# 0                        Roc Mele,Roc Meler,Roc Mélé  42.58765    1.74180
# 1  Pic de la Font-Negre,Pic de la Font-Nègre,Pic ...  42.52535    1.73343
# 2  Estany de les Abelletes,Etang de Font-Negre,Ét...  42.52915    1.73362
# 3  Port Vieux de Coume d'Ose,Port Vieux de Coume ...  42.62568    1.61823
# 4     Port de la Cabanette,Porteille de la Cabanette  42.60000    1.73333
#
#   feature class feature code country code    cc2 admin1 code admin2 code  \
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Load the data
file_path = 'featureCodes_en.txt'
df = pd.read_csv(file_path, sep='\t', header=None, names=['Feature', 'Description'])

# Split the 'Feature' into 'Feature Class' and 'Feature Code' if needed
df['Feature Class'] = df['Feature'].apply(lambda x: x.split('.')[0])
df['Feature Code'] = df['Feature'].apply(lambda x: x.split('.')[1])

# Text preprocessing and vectorization
vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
X = vectorizer.fit_transform(df['Description'])
y = df['Feature Class']

# Splitting data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Model training
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Model evaluation
predictions = model.predict(X_test)
print(classification_report(y_test, predictions))

# %%
import pandas as pd

# Define the file path for the input text file and the output CSV file
input_file_path = 'featureCodes_en.txt'
output_csv_path = 'features.csv'

# Define the column headers based on the structure you provided
column_headers = [
    
]

# Use pandas to read the tab-delimited file
df = pd.read_csv(input_file_path, delimiter='\t', names=column_headers, low_memory=False)

# Save the DataFrame to a CSV file
df.to_csv(output_csv_path, index=False)

# Print the first few rows of the DataFrame to verify
print(df.head())

# %%
import pandas as pd

# Assuming the CSV data is loaded into a DataFrame called df
df = pd.read_csv('/Users/sandroamaglobeli/Documents/GitHub/Hackathon24/Travel/geonames.csv')
# Combine the feature class and feature code columns
df['Combined_Feature'] = df['feature class'] + "." + df['feature code']

# The resulting DataFrame has a new column 'Combined_Feature' with combined class and code
df.head()
# Out:
# /var/folders/bd/lyhf2lcs6bbfq6rcy7wkm3rw0000gn/T/ipykernel_56061/3963895740.py:4: DtypeWarning: Columns (9,10,11,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/sandroamaglobeli/Documents/GitHub/Hackathon24/Travel/geonames.csv')
#    geonameid                          name                     asciiname  \
# 0    2994701                     Roc Meler                     Roc Meler
# 1    3017832          Pic de les Abelletes          Pic de les Abelletes
# 2    3017833       Estany de les Abelletes       Estany de les Abelletes
# 3    3023203  Port Vieux de la Coume d’Ose  Port Vieux de la Coume d'Ose
# 4    3029315          Port de la Cabanette          Port de la Cabanette
#
#                                       alternatenames  latitude  longitude  \
# 0                        Roc Mele,Roc Meler,Roc Mélé  42.58765    1.74180
# 1  Pic de la Font-Negre,Pic de la Font-Nègre,Pic ...  42.52535    1.73343
# ...

# %%
df2= pd.read_csv('/Users/sandroamaglobeli/Documents/GitHub/Hackathon24/Travel/featureCodes_en.csv')
df2.head()
# Out:
#   Combined Feature_code Class  \
# 0   A.ADM1         ADM1     A
# 1  A.ADM1H        ADM1H     A
# 2   A.ADM2         ADM2     A
# 3  A.ADM2H        ADM2H     A
# 4   A.ADM3         ADM3     A
#
#                                            Keyword  \
# 0              first-order administrative division
# 1   historical first-order administrative division
# 2             second-order administrative division
# 3  historical second-order administrative division
# 4              third-order administrative division
#
#                                          Description
# 0  a primary administrative division of a country...
# 1       a former first-order administrative division
# 2  a subdivision of a first-order administrative ...
# 3      a former second-order administrative division
# 4  a subdivision of a second-order administrative...
